# %% [markdown]
# # Requests: HTTP for Humans
#
# HTTP (HyperText Transfer Protocol) is the foundation of data communication on the web. It defines how messages are formatted and transmitted, and how web servers and browsers should respond to various commands.
#
# The requests library in Python makes it easy to send HTTP requests and receive responses. It abstracts the complexities of making HTTP requests behind a simple API, making it one of the most popular libraries for web scraping and API interaction.
#
# HTTP Methods:
#
# | HTTP Method | Purpose                   | Example                             |
# |-------------|---------------------------|-------------------------------------|
# | **GET**     | Retrieve data             | Fetch a webpage                     |
# | **POST**    | Submit data               | Submit a form                       |
# | **PUT**     | Update or create resource | Update user profile                 |
# | **DELETE**  | Remove a resource         | Delete a user account               |
# | **PATCH**   | Partial modification      | Update specific user profile fields |
# | **HEAD**    | Retrieve headers          | Check resource metadata             |
# | **OPTIONS** | Describe options          | Determine allowed methods           |
# | **TRACE**   | Message loop-back test    | Debug request path                  |
#
#
#
# NOTE:
#
# ```bash
# pip install requests
# ```
#
# ### GET Request
#
# A GET request is used to request data from a specified resource.

# %%
import requests

response = requests.get('https://httpbin.org/get')
print(response.status_code)
print(response.text)
print(type(response.text))
# Out:
# 200
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.28.2",
#     "X-Amzn-Trace-Id": "Root=1-6649f94c-7e93ea5f64a252da24b30e99"
#   },
#   "origin": "86.49.255.169",
#   "url": "https://httpbin.org/get"
# }
#
# <class 'str'>

# %%
import requests

response = requests.get('https://www.google.com/')
print(response.status_code)
print(response.text)
print(type(response.text))
# Out:
# 200
# ...

# %% [markdown]
# ### POST Requests
#
# A POST request is used to send data to a server to create/update a resource.

# %%
import requests

data = {'key': 'value'}
response = requests.post('https://httpbin.org/post', data=data)
print(response.status_code)
print(response.text)
# Out:
# 200
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key": "value"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "9",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.28.2",
#     "X-Amzn-Trace-Id": "Root=1-6649f94d-380bc2104d6f13aa3c5c683c"
#   },
#   "json": null,
#   "origin": "86.49.255.169",
#   "url": "https://httpbin.org/post"
# }

# %% [markdown]
# ## Requesting GitHub API

# %%
import requests

response = requests.get('https://api.github.com')
print(response.status_code)
print(response.text)
print(type(response.text))
# Out:
# 200
# ...

# %%
import requests
response = requests.get('https://api.github.com')

data = response.json()
print(response.status_code)
print(data)
print(type(data))

print(data["current_user_url"])
# Out:
# 200
# ...

# %%
# https://docs.github.com/en/rest/repos/repos?apiVersion=2022-11-28#get-a-repository

import requests

# Repository details
owner = 'CVUT-FS-12110'
repo = 'Python-for-Scientific-Computations-and-Control'

# GitHub API URL for the repository
url = f'https://api.github.com/repos/{owner}/{repo}'

# Make the GET request
response = requests.get(url)

repo_data = response.json()
print(repo_data)

# Optional: If you want to format the output nicely
import json
print(json.dumps(repo_data, indent=4))
# Out:
# {'id': 216564296, 'node_id': 'MDEwOlJlcG9zaXRvcnkyMTY1NjQyOTY=', 'name': 'Python-for-Scientific-Computations-and-Control', 'full_name': 'CVUT-FS-12110/Python-for-Scientific-Computations-and-Control', 'private': False, 'owner': {'login': 'CVUT-FS-12110', 'id': 56829313, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU2ODI5MzEz', 'avatar_url': 'https://avatars.githubusercontent.com/u/56829313?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/CVUT-FS-12110', 'html_url': 'https://github.com/CVUT-FS-12110', 'followers_url': 'https://api.github.com/users/CVUT-FS-12110/followers', 'following_url': 'https://api.github.com/users/CVUT-FS-12110/following{/other_user}', 'gists_url': 'https://api.github.com/users/CVUT-FS-12110/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/CVUT-FS-12110/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/CVUT-FS-12110/subscriptions', 'organizations_url': 'https://api.github.com/users/CVUT-FS-12110/orgs', 'repos_url': 'https:
# ...

# %% [markdown]
# ### Playing with ISS api

# %%
# http://open-notify.org/Open-Notify-API/ISS-Location-Now/

import requests

response = requests.get('http://api.open-notify.org/iss-now.json')
print(response.status_code)
print(response.text)
print(type(response.text))
# Out:
# 200
# {"iss_position": {"longitude": "170.8437", "latitude": "33.9268"}, "message": "success", "timestamp": 1716123982}
# <class 'str'>

# %% [markdown]
# NOTE:
#
# ```bash
# pip install requests matplotlib basemap
# ```

# %%
import requests
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# Fetch the JSON data
response = requests.get('http://api.open-notify.org/iss-now.json')
data = response.json()

# Extract latitude and longitude from the JSON data
longitude = float(data['iss_position']['longitude'])
latitude = float(data['iss_position']['latitude'])

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(10, 5))

# Create a Basemap instance
m = Basemap(projection='mill', llcrnrlat=-90, urcrnrlat=90,
            llcrnrlon=-180, urcrnrlon=180, resolution='c', ax=ax)

# Draw coastlines and countries
m.drawcoastlines()
m.drawcountries()

# Plot the ISS position
x, y = m(longitude, latitude)
m.plot(x, y, 'ro', markersize=10, label='ISS')

# Add a legend
plt.legend(loc='lower left')

# Add a title
plt.title('Current Location of the ISS')

# Show the plot
plt.show()
