# %% [markdown]
# # Genetic algorithms

# %% [markdown]
# ## Introduction

# %% [markdown]
# Genetic algorithms are algorithms inspired by Charles Darwin's theory of natural evolution. Those algorithms are trying to behave like real nature one featuring populations, proliferation, mutation etc. Where individuals are selected base on some criteria, which decides if individual transmits genes over to next generation.

# %% [markdown]
# ## Natural Selection - since 1859 with love

# %% [markdown]
# Process of natural selection is key to genetic algorithms. We start with some(usualy random) population and then we have some tools to operate with that generation. Usualy, five phases are considered in genetic algorithms:
# <ul>
#     <li> Initial generation
#     <li> Fitness function
#     <li> Selection
#     <li> Crossover
#     <li> Mutation
# </ul>
# Basically, we calculate the best fitting individuals, those individuals make offsprings(with corosover and mutatiton) and those offsprings replace the worst fitting individuals.

# %%
# Imports
import random

# %%
class individual:
    def __init__(self, genes):
        self.genes = genes
    def __str__(self):
        return 'Individual with genes:  '+str(self.genes)
    
    def calc_fit(self, function):
        return function(self.genes)
    
    def mutate(self, propability, function):
        if random.random() < propability:
            self.genes = function(self.genes)
        else:
            pass

def fit(genes):
    score = 0
    for g in genes:
        if g == 'a':
            score +=1
        else:
            pass
    return score

def mutation(genes):
    index = random.randint(0,len(genes)-1)
    try:
        pom = genes[index]
        genes[index] = genes[index+1]
        genes[index+1] = pom
    except:
        pom = genes[index]
        genes[index] = genes[index-1]
        genes[index-1] = pom
    return genes


def copulate(i1,i2):
    lengen = len(i1.genes)
    new_genes = i1.genes + i2.genes
    while lengen < len(new_genes):
        _ = new_genes.pop(int(len(new_genes)/2))
    return individual(new_genes)

def proliferate(individuals):
    i = 0
    j = 0
    while i <int(len(individuals)/2):
        new_i = copulate(individuals[i],individuals[i+1])
        individuals[-1-j] = new_i
        i+=2
        j+=1
    return individuals
        

class island:
    def __init__(self,individuals):
        self.individuals = individuals
    
    def step(self,proliferate,propability_mutation=0.1):
        dummy = x = self.individuals
        self.individuals = sorted(x,key = lambda x: x.calc_fit(fit),reverse=True)
        self.individuals = proliferate(self.individuals)
        for ind in self.individuals:
            ind.mutate(propability_mutation,mutation)
    
    def __str__(self):
        string = """\n"""
        for ind in self.individuals:
            string += str(ind)
            string += '\n'
        return string
        
        

    
i1 = individual(['a','a','b','d','a','c'])
print(i1)
i1.mutate(0.9,mutation)   
print(i1) 
print(i1.calc_fit(fit))
# Out:
# Individual with Genes:  ['a', 'a', 'b', 'd', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'c']
# 3

# %%
print(i1.genes)
# Out:
# ['a', 'a', 'b', 'a', 'd', 'c']

# %%
G = ['a','b','c','d']
Individuals = []
for _ in range(20):
    genes = []
    for char in range(6):
        genes.append(random.choice(G))
    Individuals.append(individual(genes))

# %%
Population = island(Individuals)

# %%
import time
print('Initial Generation')
print(Population)
print('___________________ \n')

for i in range(40):
    Population.step(proliferate)
    print('Generation {}'.format(i))
    print('___________________ \n')
    print(Population)
# Out:
# Initial Generation
#
# Individual with Genes:  ['a', 'b', 'd', 'c', 'a', 'c']
# Individual with Genes:  ['b', 'c', 'd', 'b', 'b', 'a']
# Individual with Genes:  ['c', 'a', 'b', 'c', 'a', 'd']
# Individual with Genes:  ['d', 'a', 'd', 'd', 'd', 'd']
# Individual with Genes:  ['b', 'b', 'b', 'b', 'a', 'c']
# Individual with Genes:  ['c', 'c', 'a', 'd', 'c', 'd']
# Individual with Genes:  ['a', 'd', 'b', 'd', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'b', 'c', 'd']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['d', 'a', 'b', 'c', 'c', 'c']
# Individual with Genes:  ['a', 'b', 'c', 'c', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'd', 'b', 'c']
# Individual with Genes:  ['a', 'c', 'b', 'a', 'b', 'a']
# Individual with Genes:  ['d', 'a', 'b', 'c', 'b', 'd']
# Individual with Genes:  ['c', 'c', 'd', 'c', 'c', 'a']
# Individual with Genes:  ['c', 'c', 'b', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'c', 'b', 'd', 'a', 'd']
# Individual with Genes:  ['d', 'a', 'c', 'a', 'd', 'c']
# Individual with Genes:  ['c', 'd', 'd', 'b', 'a', 'b']
# Individual with Genes:  ['d', 'a', 'd', 'c', 'd', 'b']
#
# ___________________
#
# Generation 0
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['a', 'c', 'b', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'c', 'a', 'c']
# Individual with Genes:  ['c', 'a', 'b', 'c', 'a', 'd']
# Individual with Genes:  ['a', 'b', 'd', 'd', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'c', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'd', 'b', 'c']
# Individual with Genes:  ['c', 'c', 'b', 'c', 'a', 'a']
# Individual with Genes:  ['d', 'a', 'c', 'a', 'd', 'c']
# Individual with Genes:  ['b', 'c', 'd', 'b', 'b', 'a']
# Individual with Genes:  ['d', 'a', 'd', 'd', 'd', 'd']
# Individual with Genes:  ['b', 'b', 'b', 'b', 'a', 'c']
# Individual with Genes:  ['c', 'c', 'a', 'd', 'c', 'd']
# Individual with Genes:  ['a', 'b', 'd', 'b', 'c', 'd']
# Individual with Genes:  ['d', 'a', 'b', 'c', 'c', 'c']
# Individual with Genes:  ['d', 'a', 'c', 'b', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'd', 'b', 'c', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'c', 'a', 'd']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
#
# Generation 1
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'c', 'b', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'c', 'a', 'c']
# Individual with Genes:  ['c', 'a', 'b', 'c', 'a', 'd']
# Individual with Genes:  ['a', 'b', 'd', 'd', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'c', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'd', 'b', 'c']
# Individual with Genes:  ['c', 'c', 'b', 'c', 'a', 'a']
# Individual with Genes:  ['d', 'a', 'c', 'a', 'd', 'c']
# Individual with Genes:  ['d', 'a', 'c', 'b', 'b', 'a']
# Individual with Genes:  ['a', 'd', 'b', 'c', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'c', 'a', 'd']
# Individual with Genes:  ['b', 'c', 'd', 'b', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'c', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'c', 'a', 'd']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
#
# Generation 2
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'c', 'b', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'c', 'a', 'c']
# Individual with Genes:  ['c', 'a', 'b', 'c', 'd', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'd', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'c', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'd', 'b', 'c']
# Individual with Genes:  ['c', 'c', 'b', 'c', 'a', 'a']
# Individual with Genes:  ['d', 'a', 'c', 'a', 'd', 'c']
# Individual with Genes:  ['d', 'a', 'c', 'b', 'b', 'a']
# Individual with Genes:  ['c', 'a', 'b', 'd', 'b', 'a']
# Individual with Genes:  ['a', 'c', 'b', 'a', 'c', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
#
# Generation 3
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'c', 'b', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'c', 'a', 'c']
# Individual with Genes:  ['c', 'a', 'b', 'c', 'd', 'a']
# Individual with Genes:  ['a', 'b', 'd', 'd', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'c', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'd', 'b', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
#
# Generation 4
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'c', 'b', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
#
# Generation 5
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
#
# Generation 6
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
#
# Generation 7
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
#
# Generation 8
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
#
# Generation 9
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
#
# Generation 10
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
#
# Generation 11
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
#
# Generation 12
# ___________________
#
#
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
#
# Generation 13
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'd']
#
# Generation 14
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 15
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 16
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 17
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 18
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'b', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 19
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 20
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 21
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 22
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 23
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'c', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 24
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'c', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'c', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 25
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'c', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 26
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 27
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'd', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 28
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 29
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 30
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'b', 'c', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 31
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 32
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['b', 'a', 'c', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 33
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'd', 'a']
#
# Generation 34
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 35
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 36
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 37
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'b', 'b', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 38
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
#
# Generation 39
# ___________________
#
#
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'd']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'c', 'a', 'a', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'a', 'b', 'a', 'c', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'c', 'a', 'a']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'a', 'c']
# Individual with Genes:  ['a', 'b', 'a', 'a', 'c', 'a']
# Individual with Genes:  ['b', 'a', 'a', 'b', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'b']
# Individual with Genes:  ['b', 'a', 'a', 'a', 'a', 'd']
