# %% [markdown]
# # Task 6 - NumPy and Matplotlib
# ## Convolutional filter:
#
# <ol>
#   <li>See https://en.wikipedia.org/wiki/Kernel_(image_processing)</li>
#   <li>Program a function, which applies a convolutional filter for 2D image. <strong>You can use only NumPy package!</strong>  </li>
#   <li>Input should be an image and convolutional filter (n x n). Output should be filtered image</li>
#   <li>Visualize the result: Visualization should consist of two images "before" and "after" filtering. It should also have labels and title. <strong>You can use only Matplotlib package!</strong></li>
# </ol>

# %% [markdown]
# ###  How to import image into NumPy array using Matplotlib

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("foo.png") #import image into numpy array
impgplot = plt.imshow(img) #plot the image
